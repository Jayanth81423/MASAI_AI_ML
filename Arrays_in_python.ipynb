# %% [markdown]
# | Type Code | C Type   |Python Type | size in bytes|
# |-----------|----------|----------|-------|
# | 'c'    | Char   |  Character   |      1  |
# | 'b'    | Signed char   | Int   |    1  |
# |'b'|Unsigned char|Int|1|
# |'u'|PY_UNICODE|Unicode Character|2|
# |'h'|Signed short|Int|2|
# |'H'|Unsined shot|Int|2|
# |'i'|Signed int|Int|2|
# |'I'|Unsigned int|Long|2|
# |'l'|Signed long|Int|4|
# |'L'|Unsigned long|Long|4|
# |'f'|Float|Float|4|
# |'d'|Double|Float|8|

# %%
from array import *
arr = array('i',[-1,2,3,4,5])
print (arr)

# %%
print(arr.buffer_info())

# %%
for i in arr:
  print (i )

# %%
for pnt in range(5):  # It gives the array value in the index with index value
  print(pnt,arr[pnt])

# %%
arr.reverse()
print(arr)

# %%
arr.append(10)  # To add the element to the last of an array
print(arr)

# %%
arr.remove(2)   # It remove the given element from the array witch comes first
print(arr)

# %%
print(arr[2]) # Prints the value at index 2
print(arr.index(3))

# %%
arr2=array('i',[])
x= int(input('enter size of array'))
print('enter %d elements' %x)
for i in range(x):
  n= int (input())
  arr2.append(n)
print(arr2)
