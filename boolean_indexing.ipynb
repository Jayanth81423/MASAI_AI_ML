# %%
import numpy as np

# %%
jay=np.array([4,5,5,2,6,4,8,4,6,89,498,2,])

# %%
ram=jay.reshape(3,-1)

# %%
print (ram)

# %%
mask =ram == 5

# %%
ram[mask]=0
print(ram)

# %%
import pandas as pd

# %%
pip install quandl

# %%
import quandl

# %%
df= quandl.get ('WIKI/GOOGL')

# %%
print(df.hed())
