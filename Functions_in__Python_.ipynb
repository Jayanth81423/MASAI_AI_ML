# %% [markdown]
# # A function is a set on code  that performs some task

# %%
def wellcome():     # Simple function defination or defining the function
  print('Good morning')
wellcome()

# %%
def add(a=0,b=0):  # Default arguments
  total= a+b
  print('the sum is',total)
add(b=34)   # By givine default argument we can give single value

# %%
def add2(*a):
  total = 0
  for i in a :
    total=total+ i
  print('the sum is',total)
add2(10,5,8,9,5,5,25,69,54)
add2(10,5,8,9,5,5,25,69,54)
