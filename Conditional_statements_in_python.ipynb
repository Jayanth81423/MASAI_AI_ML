# %% [markdown]
# # if (condition)
# * statements to execute if conditon is true
# # else:
# * Executes else bolck if condition is false

# %%
deepika=50   # 20/2=10   20%2=0
deepika%2
# Out:
# 0

# %%
i=20
if i%2 == 0:
  print(f"the given number {i} is even")
else:
  print(f'The given number {i} is odd ')
# Out:
# the given number 20 is even

# %%
i= int(input("give a number"))
if i%3==0:
    print(f"the given number {i} is divisible by 3")
else:
    print(f"the ginen number {i} is not divisible by 3")
# Out:
# the ginen number 23 is not divisible by 3

# %% [markdown]
# # Nested if statement
# * Syntax-
#     if (condition)
#       > executes if condition2 is true
#       if (condition2):
#         >executes if condition2 is true
#       -condition2 ends here
#     -condition1 ends here

# %%
c=int(input('enter a number less then 25 '))  #
if c<25:
   print(f"The given number {c} is lessthen 25")  #
  #  if c%2==0:
  #    print(f'The given number {c} is even number')
  #    break           #  When both the if statements are true the loop breaks here.
  #  else:
  #    print(f'the given number {c} is odd number')
else:
     print('Give a number greater then 25')   # Until the user enter the numbre less then 25 the loop continues
# Out:
# Give a number greater then 25

# %% [markdown]
# # if-elif-else statement

# %%
var=str(input('enter a letter '))
if var=='a':
  print("you I've given a vowel")
elif var=='e':
  print("you I've given a vowel")
elif var=='i':
  print("you I've given a vowel")
elif var=='o':
  print("you I've given a vowel")
elif var=='u':
  print("you I've given a vowel")
else:
  print("you I've given a consonant")
