# %%
import pandas as pd

# %%
import os
print(os.getcwd())   # replace "data.csv" with your file name
# Out:
# c:\Users\OMSAR\Documents\GitHub\MASAI_AI_ML

# %%
df.isnull()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 df.isnull()
#
# NameError: name 'df' is not defined
