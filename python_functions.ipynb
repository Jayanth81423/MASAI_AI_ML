# %% [markdown]
# # abs function (absolute )
# it allways returns the positive value

# %%
x= -435.534
print(abs(x))

# %% [markdown]
# # Math library

# %%
import math

# %% [markdown]
# #  exponential value

# %%
x= 10
print(math.exp(x)) # hear the default  exponential value is 2.718281828459045

# %%
math.e # to find the default value of e

# %%
# value of PI is
math . pi

# %% [markdown]
# # To find the square root of a number we use (sqrt)
# It allways return the floating value as the result

# %%
print(math.sqrt(20))

# %% [markdown]
# # To find the max value from a list we use (max())

# %%
max (12,34,5432,24,423,32445,2643)

# %% [markdown]
# # To find the min value from a list we use (min())

# %%
min (12,34,5432,24,423,32445,2643)
