# %% [markdown]
# # Tuples
#    ->.Tuple is collection of immutable heterogeneous python objects
#
#    ->. Every object  is addressed with indices

# %% [markdown]
# # 1.Creating a tuple x

# %% [markdown]
# #(1.1). Creating a tuple x with parentheses

# %%
x= (2,"f",'d',5,3,4,8,94,'jay')
print(x)
print(type(x))

# %% [markdown]
# #(1.2). Creating a tuple x with out a  parentheses

# %%
tup1=2,4,3,2,1,9,
print(tup1,type(tup1))

# %% [markdown]
# #2. accessing elements in tuple

# %%
city='pune','Bangalore','Delhi','Mumbai','Chennai',
print(city)

# %%
city[1]

# %% [markdown]
# # 3.Concatenation of tuple

# %%
num=1,2,3,4,5,6,
print(num)
print(city)

# %%
print(city+num)

# %% [markdown]
# # 4.Nest tuples
# -> A tuple in another tuple

# %%
nest=(city,num)
print(nest)

# %% [markdown]
# #5. Repetition of tuple elements

# %%
rep=('python',)*5
print(rep)

# %%
print(rep*5) # An snother way to repeat tupil elements

# %%
rep

# %% [markdown]
# #6. Slicing the tuple

# %%
num

# %%
num[1:]

# %%
num[::-1]

# %% [markdown]
# #7.Unpacking tuple

# %%
tuple('Simplilearn')

# %%
print(num)

# %%
a,b,c,d,e,f=num
print(a,b,c,d,e,f)

# %% [markdown]
# When you don't know how many elements in tuple

# %%
a,*b,c=num # First element goes to a, last element goes to c and elements B/W goes to list *b
print(a,b,c)

# %% [markdown]
# #8.Deleting a tuple

# %%
tuple_to_del=(1,2,3,4,5,6)
print(tuple_to_del)

# %%
del tuple_to_del

# %%
print(tuple_to_del)

# %% [markdown]
# #9. Built in functions of tuple

# %%
num1=(3,5,2,2,3,2,2,5,6,8,79,25,4,96,41,52,6)

# %%
num1.count(2) # To know the count of given element

# %%
sum(num1) # It gives the sum of all elements in tuple

# %%
len(num1) # It gives the length of tuple

# %%
max(num1) # It gives the maximum element in tuple

# %%
min(num1) # It gives the minimum element in tuple

# %% [markdown]
# # 10.Converting list to tuple

# %%
lst=[1,2,3,4]
print(lst)
print(type(lst))

# %%
tpl=tuple(lst)

# %%
print(tpl)
print(type(tpl))

# %% [markdown]
# #11. Neasting tuples in a list

# %%
lst1=[(1,2,3),('a','b','c'),(True,False)]
print(lst1)

# %%
lst1.append(("Tuple","Inside","list"))
print(lst1)

# %%
lst1.remove((1,2,3))
print(lst1)

# %% [markdown]
# #12.Nesting Lists within the tuples

# %%
tpl1=(['a','d','c','d'],['e','f','g','h'])
print(tpl1)

# %%
tpl1[0].append('z')
print(tpl1)

# %%
tpl1[0].remove('z')
print(tpl1)
