# %%
import numpy as np

# %%
foo= np.arange(start=1,stop=9)
print(foo)

# %% [markdown]
# #reshaping the numpay array

# %%
foo.reshape(2,4) #one way to reshape an array

# %% [markdown]
# Both work in the same way

# %%
np.reshape(a=foo,newshape=(1,8))  # another way to reshape an array

# %%
bar = foo.reshape(4,2)
print(bar)

# %%
bar.reshape((4,2),order='f')

# %%
bar.reshape((2,2,2),order='f')

# %%
bar.reshape(-1,1) # when u have no idea about how many rows or columns to give

# %%
print (bar)
bar.T   # for transpose an array

# %%
np.transpose(bar) # to be more specific

# %%
bar=np.kron(foo,foo)
print(bar)
